# %% [markdown]
# ## Exponential Distribution
# The exponential distribution is often used to model the time between events in a Poisson process. It is characterized by its rate parameter (λ), which is the inverse of the mean.
#
# - Model time between events
# - Right-skewed
# - Memoryless property
#
# Examples:
# - Time between customer arrivals
# - Equipment failure times
# - Phone call durations

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon

# Exponential distribution
exponential_data = np.random.exponential(scale=2.0, size=1000)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(exponential_data, bins=30, alpha=0.7, color='red', edgecolor='black', density=True)
plt.title('Exponential Distribution')
plt.xlabel('Time between events')
plt.ylabel('Density')

plt.subplot(1, 2, 2)
# PDF overlay
x = np.linspace(0, exponential_data.max(), 100)
pdf = expon.pdf(x, scale=2.0)
plt.hist(exponential_data, bins=30, alpha=0.5, color='red', edgecolor='black', density=True)
plt.plot(x, pdf, 'b-', linewidth=2, label='Theoretical PDF')
plt.title('Exponential Distribution with PDF')
plt.xlabel('Time between events')
plt.ylabel('Density')
plt.legend()

plt.tight_layout()
plt.show()
